# %% [markdown]
# ### dividing our images into train and  test sets

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato'
# Out:
# /content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato

# %%
import os, os.path
import shutil, os
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___healthy'
print (len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))
# Out:
# 1400

# %%
img_files = []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___healthy'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk("/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___Bacterial_spot", topdown=False):
   for name in files:
     if i>0:
       img_files.append(os.path.join(root, name))
       i=i-1

# %%
len(img_files)
# Out:
# 280

# %%
img_Tomato___Bacterial_spot = []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___Bacterial_spot'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Bacterial_spot.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Bacterial_spot:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Bacterial_spot')

# %%
img_Tomato___Early_blight = []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___Early_blight'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Early_blight.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Early_blight:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Early_blight')

# %%
img_Tomato___Late_blight = []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___Late_blight'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Late_blight.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Late_blight:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Late_blight')

# %%
img_Tomato___Leaf_Mold= []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/train/Tomato___Leaf_Mold'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Leaf_Mold.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Leaf_Mold:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Leaf_Mold')

# %%
img_Tomato___Septoria_leaf_spot = []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/train/Tomato___Septoria_leaf_spot'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Septoria_leaf_spot.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Septoria_leaf_spot:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Septoria_leaf_spot')

# %%
img_Tomato___Spider_mites= []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___Spider_mites Two-spotted_spider_mite'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Spider_mites.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Spider_mites:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Spider_mites Two-spotted_spider_mite')

# %%
img_Tomato___Target_Spot = []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___Target_Spot'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Target_Spot.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Target_Spot:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Target_Spot')

# %%
img_Tomato___Tomato_Yellow_Leaf_Curl_Virus = []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___Tomato_Yellow_Leaf_Curl_Virus'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Tomato_Yellow_Leaf_Curl_Virus.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Tomato_Yellow_Leaf_Curl_Virus:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Tomato_Yellow_Leaf_Curl_Virus')

# %%
img_Tomato___Tomato_mosaic_virus = []
DIR = '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/Tomato___Tomato_mosaic_virus'
i=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]) *0.2

for root, dirs, files in os.walk(DIR):
   for name in files:
     if i>0:
       img_Tomato___Tomato_mosaic_virus.append(os.path.join(root, name))
       i=i-1
for f in img_Tomato___Tomato_mosaic_virus:
    shutil.move(f, '/content/drive/MyDrive/stage orange/Plant_leave_diseases_dataset_without_augmentation/tomato/test/Tomato___Tomato_mosaic_virus')
